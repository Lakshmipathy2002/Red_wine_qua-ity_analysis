# %% [markdown]
# # Red Wine quality prediction data analysis
#
# The aim of wine quality prediction is to develop models and algorithms that can accurately predict the quality of a wine based on various input features. These features can include factors such as chemical composition, physical properties, and sensory characteristics of the wine.

# %% [markdown]
# # import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# # About Libraries
#
# NumPy is a powerful numerical computing library for Python. It provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these elements. NumPy is a fundamental package for scientific computing in Python.
#
# Pandas is a powerful open-source data manipulation and analysis library for Python. It provides data structures for efficiently storing and manipulating large datasets and tools for working with structured data seamlessly. Pandas is built on top of the NumPy library and is a fundamental component of the Python data science ecosystem.
#
# Matplotlib is a popular 2D plotting library for Python that produces high-quality charts and figures. It provides a wide variety of plotting options and customization features, making it suitable for a range of visualization tasks. Matplotlib is often used in conjunction with other libraries such as NumPy and Pandas for data analysis and visualization.
#
# pyplot is a module within the Matplotlib library that provides a collection of functions for creating various types of plots and charts with minimal coding effort. It is a convenient interface for Matplotlib that allows you to create figures, axes, and plots with a simple and MATLAB-like syntax. Many of the examples I provided in the previous response use pyplot functions.
#
# Seaborn is a statistical data visualization library built on top of Matplotlib. It provides a high-level interface for creating attractive and informative statistical graphics. Seaborn comes with several built-in themes and color palettes to make it easy to create visually appealing plots. It is particularly well-suited for exploring and visualizing complex datasets with multiple variables.
#
# The train_test_split function from the sklearn.model_selection module in scikit-learn is used for splitting a dataset into two subsets: one for training a machine learning model and another for testing or validating the model's performance. This process is essential to assess how well the trained model generalizes to new, unseen data.
#
# The RandomForestClassifier is a popular machine learning model provided by scikit-learn's ensemble module. It belongs to the ensemble methods category and is an ensemble of decision trees. Random Forests are known for their flexibility, robustness, and ability to handle a variety of data types and tasks, including classification.
#
# The accuracy_score function from scikit-learn's metrics module is commonly used to evaluate the accuracy of a classification model's predictions. Accuracy is a measure of the overall correctness of the model, representing the ratio of correctly predicted instances to the total number of instances.

# %% [markdown]
# # Data Collection

# %%
#loading the data set to a pandas dataframe
wine_dataset=pd.read_csv(r'C:\Users\Lakshmi Pathy\Downloads\archive (1)\winequality-red.csv')

# %%
#number of rows and columns in the data set
wine_dataset.shape
# Out:
# (1599, 12)

# %%
#first five rows of dataset
wine_dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#checking missing values from column wise
wine_dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # Data Analysis And Visualisation

# %%
#statistical measures of the data set
wine_dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#number of values for each quality
sns.catplot(x='quality',data=wine_dataset,kind='count')

# %%
#volatile acidity vs quality
plot=plt.figure(figsize=(5,5))
sns.barplot(x='quality',y='volatile acidity',data=wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
#citric acid vs quality
plot=plt.figure(figsize=(5,5))
sns.barplot(x='quality' ,y='citric acid',data=wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
#volatile acidity vs quality
plot=plt.figure(figsize=(5,5))
sns.barplot(x='quality',y='fixed acidity',data=wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %%
#volatile acidity vs quality
plot=plt.figure(figsize=(5,5))
sns.barplot(x='quality',y='residual sugar',data=wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='residual sugar'>

# %%
#volatile acidity vs quality
plot=plt.figure(figsize=(5,5))
sns.barplot(x='quality',y='chlorides',data=wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='chlorides'>

# %%
#volatile acidity vs quality
plot=plt.figure(figsize=(5,5))
sns.barplot(x='quality',y='free sulfur dioxide',data=wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='free sulfur dioxide'>

# %% [markdown]
# # Corelation

# %%
corelation=wine_dataset.corr()

# %%
#constructing a heatmap to understand the corelation between the columns
plt.figure(figsize=(10,10))
sns.heatmap(corelation,cbar=True,square=True,fmt='.1f',annot=True,annot_kws={'size':8},cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# # Data preprosesing

# %%
#seperate the data and label
x=wine_dataset.drop('quality',axis=1)

# %%
print(x)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # Label Binarisation

# %%
y=wine_dataset['quality'].apply(lambda y_value:1 if y_value>=7 else 0)

# %%
print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1599, dtype: int64

# %% [markdown]
# # Train and test split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
print(y.shape,y_train.shape,y_test.shape)
# Out:
# (1599,) (1279,) (320,)

# %% [markdown]
# # Model Training
#
# Random Forest Classifier

# %%
model= RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # Model Evaluation
#
# Accuracy Score

# %%
#accuracy on test data
x_test_prediction=model.predict(x_test)
test_data_accuracy=accuracy_score(x_test_prediction,y_test)

# %%
print('accuracy:',test_data_accuracy)
# Out:
# accuracy: 0.93125

# %% [markdown]
# # Building a Predictive System

# %%
input_data =(7.3,0.65,0.0,1.2,0.065,15.0,21.0,0.9946,3.39,0.47,10.0)

# changing the input data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the data as we are predicting the label for only one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if(prediction[0]==1):
    print("good quality wine")
else:
    print("bad quality wine")

import warnings

# Filter out the specific warning
warnings.filterwarnings("ignore", message="X does not have valid feature names", category=UserWarning)
# Out:
# [1]
# good quality wine
